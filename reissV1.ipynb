# %%
import requests
import re
import xlwt

wb = xlwt.Workbook()
ws = wb.add_sheet('Data')


title = ['ProductUrl','Productid','ProductTitle','Productname','Nowprize','wazprice','color','size','StockStatus','Imageurl','description']
for index ,head in enumerate(title):
	# print(head)
	ws.write(0, index, head)


mainurl_list= ['https://www.reiss.com/rw/p/suede-trucker-overshirt-mens-sakura-in-peppermint-green/?category_id=10394&gaEeList=M%20-%20Coats%20%26%20Jackets%20-%20Jackets',
'https://www.reiss.com/rw/p/suede-zip-through-jacket-mens-marlo-in-tobacco-brown/?category_id=10394&gaEeList=M%20-%20Coats%20%26%20Jackets%20-%20Jackets',
'https://www.reiss.com/rw/p/open-knit-bodycon-dress-womens-emmy-in-neutral-brown-cream/?category_id=1121&gaEeList=W%20-%20Dresses',
'https://www.reiss.com/rw/p/leather-trainers-with-perforated-detailing-mens-grendon-in-pink/?category_id=1134&gaEeList=M%20-%20Shoes',
'https://www.reiss.com/rw/p/woven-belt-mens-elmont-in-navy-blue-aw19/?category_id=10322&gaEeList=M%20-%20Acc%20-%20Belts',
'https://www.reiss.com/rw/p/patent-leather-croc-embossed-belt-mens-moro-in-black/?category_id=10322&gaEeList=M%20-%20Acc%20-%20Belts',
'https://www.reiss.com/rw/p/medallion-printed-silk-pocket-square-mens-luis-in-gold/?category_id=10407&gaEeList=M%20-%20Acc%20-%20Pocket%20Squares',
'https://www.reiss.com/rw/p/longline-mac-womens-penelope-in-navy-blue/?category_id=10347&gaEeList=W%20-%20Coats%20%26%20Jackets%20-%20Coats',
'https://www.reiss.com/rw/p/herringbone-blind-seam-overcoat-womens-lily-in-oatmeal-brown/?category_id=10347&gaEeList=W%20-%20Coats%20%26%20Jackets%20-%20Coats',
'https://www.reiss.com/rw/p/cotton-blend-slim-fit-blazer-mens-world-in-navy-blue/?category_id=1114&gaEeList=M%20-%20Blazers',
'https://www.reiss.com/rw/p/printed-bikini-briefs-womens-janina-in-multi-brown-cream/?category_id=1128&gaEeList=W%20-%20Swimwear',
'https://www.reiss.com/rw/p/cross-back-swimsuit-with-embroidered-detail-womens-bernice-in-red/?category_id=1128&gaEeList=W%20-%20Swimwear',
'https://www.reiss.com/rw/p/drawstring-swim-shorts-mens-sonar-in-teal-blue-green/?category_id=10515&gaEeList=M%20-%20Swimwear',
'https://www.reiss.com/rw/p/textured-striped-swim-shorts-mens-simon-in-soft-blue-white/?category_id=10515&gaEeList=M%20-%20Swimwear',
'https://www.reiss.com/rw/p/satin-clutch-bag-womens-belsize-bag-in-nude-brown-pink/?category_id=1131&gaEeList=W%20-%20Bags',
'https://www.reiss.com/rw/p/wool-cashmere-blend-beanie-womens-harri-in-cream-grey/?category_id=10325&gaEeList=W%20-%20Acc%20-%20Hats',
'https://www.reiss.com/rw/p/midi-dress-with-bow-detail-womens-jenna-in-cobalt-blue/?category_id=1121&gaEeList=W%20-%20Dresses',
'https://www.reiss.com/rw/p/tailored-v-neck-dress-womens-hartley-sleeveless-dress-in-navy-blue/?category_id=1121&gaEeList=W%20-%20Dresses',
'https://www.reiss.com/rw/p/capped-sleeve-dress-womens-belle-in-green/?category_id=1121&gaEeList=W%20-%20Dresses',
'https://www.reiss.com/rw/p/leather-gloves-womens-belle-in-camel-brown/?category_id=10323&gaEeList=W%20-%20Acc%20-%20Gloves',
'https://www.reiss.com/rw/p/floral-printed-ruffled-top-womens-alandra-print-in-ivory-white-cream-green/?category_id=1122&gaEeList=W%20-%20Tops',
'https://www.reiss.com/rw/p/silk-blend-v-neck-top-womens-chelsea-in-white-cream/?category_id=1122&gaEeList=W%20-%20Tops',
'https://www.reiss.com/rw/p/check-wool-coat-mens-arezzo-in-dark-brown/',
'https://www.reiss.com/rw/p/wool-slim-fit-blazer-mens-bologna-in-grey/',
'https://www.reiss.com/rw/p/quilted-ribbed-knit-jacket-mens-bernardi-in-grey-cream/?category_id=10394&gaEeList=M%20-%20Coats%20%26%20Jackets%20-%20Jackets',
'https://www.reiss.com/rw/p/ditsy-printed-day-dress-womens-louise-in-black-red/?category_id=12710&gaEeList=W%20-%20All%20Products',
'https://www.reiss.com/rw/p/plunge-front-swimsuit-womens-laila-in-black-ss20/?category_id=12710&gaEeList=W%20-%20All%20Products',
'https://www.reiss.com/rw/p/leather-skinny-belt-womens-lauren-in-tan-brown/?category_id=12710&gaEeList=W%20-%20All%20Products',
'https://www.reiss.com/rw/p/textured-pencil-skirt-womens-hartley-skirt-in-black/?category_id=12254&gaEeList=W%20-%20Skirts%20-%20Work%20Skirts']



output = []


for inx,mainurl in enumerate(mainurl_list):
	print(inx)
	# print(mainurl)

	resp = requests.get(mainurl)
	# print('resp:',resp)

	mainContent = resp.content.decode('UTF-8')
	with open(str(inx)+ 'home.html' ,'w',encoding = 'UTF-8') as f:
		f.write(mainContent)


	colorblock = re.findall('(colors\__list[\w\W]*?</ul>)',mainContent)

	url_list = re.findall('colors\__link[^>]*?\s*href\=\"([^>]*?)\"',colorblock[0])


	for url in url_list:
		print(url)

		myres = requests.get(url)
		# print('myres',myres)
		
		subContent = myres.content.decode('UTF-8')
		with open('sunhomepage.html','w',encoding='UTF-8') as r:
			r.write(subContent)

		productid = re.findall('productID\">([^>]*?)</span>',subContent)
		# print('ID::',productid[0])

		productTitle = re.findall('\"product\__title\"[^>]*?>([^>]*?)\s*</h1>',subContent)
		tilte = productTitle[0].strip()
		# print('tilte:',tilte)

		productdes = re.findall('product\__desc\"\>([^>]*?)</h2>',subContent)
		# print('productdes:',productdes[0])

		productColur = re.findall('\"color\"[^>]*?>([^>]*?)</span>',subContent)
		# print('colur:',productColur[0])

		priceBlock = re.findall('(product__prices[\w\W]*?</div>)',subContent)

		now_price = re.findall('inline\-\-block\">([^>]*?)</span>',priceBlock[0])
		if now_price:
			nowprice = now_price[0]
			nowprice = re.sub('\s+','',nowprice)
			nowprice = re.sub('now','',nowprice)
		# print('nowprice:',nowprice)

		waz_price = re.findall('was<\/span\>([^>]*?)</span>',priceBlock[0])

		if waz_price:
			wazprice = waz_price[0]
			# print('wazprice:',wazprice)
		else:
			wazprice = ''

		sizeblock = re.findall('(<ul\s*role\=\"radiogroup\"[\w\W]*?</ul>)',subContent)
		# print('sizeblock:',sizeblock)

		sizes_list = re.findall('(<li[\w\W]*?<\/li>)',sizeblock[0])

		carefabricBlock = re.findall('(left\"\s*role\=\"tabpanel\"\>[\w\W]*?</div>)',subContent)

		descrption = re.findall('<p>([\w\W]*?)</p>',carefabricBlock[0])
		finaldes = ' '.join(descrption)
		# print('finaldes:',finaldes)


		imgeblock = re.findall('(gallery\-nav\__inner\"\>[\w\W]*?</div>)',subContent)

		imgUrl = re.findall('<img\s*class[^>]*?\s*src\=\"([^>]*?)\?',imgeblock[0])
		imgeurl = ' , '.join(imgUrl)
		# print('imgeurl:',imgeurl)



		
		for size in sizes_list:
			sizes_temp = re.findall('radio\-squared\__num\"\>([^>]*?)</span>',size)

			stockstatus = re.findall('product-sizes\__item\s*([^>]*?)\s*"\s*>">',size)
			if stockstatus == 'js-low-stock js-has-stock':
				stock_status_flag = "Low-Stock"
			elif stockstatus == 'js-has-stock' :
				stock_status_flag = "In-Stock"
			else:
				stock_status_flag = "Out-of-Stock"
			print('stock_status_flag::',stockstatus)
			output.append([url,productid[0],tilte,productdes[0],nowprice,wazprice,productColur[0],sizes_temp,stock_status_flag,imgeurl,finaldes])
		# input('=================================')
			
	# print('output:',output)

for i, l in enumerate(output):
	for j, col in enumerate(l):
		ws.write(i+1, j, col)
		wb.save('reiss.xls')
# Out:
# 0
# https://www.reiss.com/rw/p/suede-trucker-overshirt-mens-sakura-in-peppermint-green/?category_id=10394&amp;hInd=2
# size:: <li class="product-sizes__item js-low-stock  js-has-stock">
#         <div class="radio-squared">
#             <label>
#                 <input type="radio" id="sylius_cart_item_variant_0" name="sylius_cart_item[variant]" required="required" data-product-sku="13600153000" data-product-name="Sakura-suede Trucker Jack - Peppermint" value="1616409" />
#                 <span class="radio-squared__btn select-size-option" data-reiss-event-element='{ "bind":"click", "category":"product", "action":"select size", "label":"XS" }'>
#                     <span class="radio-squared__holder " aria-label="Size XS"  role="radio">
#                         <span class="radio-squared__num">XS</span>
#                         <span class="product-sizes__item--low-stock"></span>                    </span>
#                 </span>
#             </label>
#         </div>
# ...
