title = ['URL','BRAND','TITLE','RETAILPRICE','SALEPRICE','STYLEID','COLOR','SIZE','AVAILABLE','STOCKSTATUS','IMAGEURL']
for index,header in enumerate(title):
  ws.write(0, index, header)
  
row = 1
for inx,url in enumerate(url_list):
  print(inx)
  print(url)
  myres = requests.get(url)
  # print('res:',myres)
  myContent = myres.content.decode('UTF=8')
  with open('_sub.html','w') as f:
    f.write(myContent)
  
  brandName = re.findall('brand\s*product\-details[^>]*?>([^>]*?)</a>',myContent)
  # print('brandName:',brandName[0])

  titlename = re.findall('title\-name\"\>([^>]*?)</span>',myContent)
  # print('titlename:',titlename[0])

  details_block = re.findall('section\__definition\"\>([^>]*?)</dd>',myContent)
  if details_block:
    details = details_block[1]
    # print('details:',details)
  else:
    details_block = ''


  style_id = re.findall('style\-number\"\>([^>]*?)</dd>',myContent)
  # print('style_id:',style_id[0])

  imge_url = re.findall('<img\s*alt\=\"Thumbnail[^>]*?src\=\"([^>]*?)\"',myContent)
  imageUrl = ' | '.join(imge_url)
  # print('imge_url:',imge_url[0])

  jsonContent = re.findall('INITIAL\_STATE\__\s*\=([\w\W]*?)</script>',myContent)
  # print('json:',jsonContent)

  jsondata = jsonContent[0]

  jsondata = json.loads(jsondata)
  # print('json',jsondata)
  n += 1
  productpage = jsondata['productPage']['product']['colors'][0]['sizes']
  lenOfSize = len(productpage)
  # print('lenOfSize::',lenOfSize)
  for i in range(lenOfSize):
    # print('i:::',i)
    sku = productpage[i]['sku']
    value = productpage[i]['value']
    isAvailable	 = productpage[i]['isAvailable']
    if isAvailable == 'True':
      Available = 'YES'
    else:
      Available = 'NO'
    lowQuantity = productpage[i]['lowQuantity']
    color = productpage[i]['color']
    retail = productpage[i]['prices']['retail']
    sale = productpage[i]['prices']['sale']




    print('url:',url)
    print('brandName:',brandName[0])
    print('titlename:',titlename[0])
    print('retailprice:',retail)
    print('salesprice:',sale)
    print('style_id:',style_id[0])
    print('color::',color)
    print('size::',value)
    print('isAvailable::',Available)
    print('lowQuantity::',lowQuantity)
    print('imge_url:',imageUrl)

    # input('==============')

    
  
    ws.write(row,0,url)
    ws.write(row,1,brandName[0])
    ws.write(row,2,titlename[0])
    ws.write(row,3,retail)
    ws.write(row,4,sale)
    ws.write(row,5,style_id[0])
    ws.write(row,6,color)
    ws.write(row,7,value)
    ws.write(row,8,Available)
    ws.write(row,9,lowQuantity)
    ws.write(row,10,imageUrl)
    row = row+1
    wb.save('nordstromrack.xls')
# Out:
# 0
# https://www.nordstromrack.com/events/355416/products/3147919/maaji-azure-heavenly-one-piece-swimsuit?color=BLUE
# url: https://www.nordstromrack.com/events/355416/products/3147919/maaji-azure-heavenly-one-piece-swimsuit?color=BLUE
# brandName: Maaji
# titlename: Azure Heavenly One-Piece Swimsuit
# retailprice: 154
# salesprice: 67.97
# style_id: 3050SOH03
# color:: BLUE
# size:: S
# isAvailable:: True
# lowQuantity:: 15
# imge_url: https://www.hautelookcdn.com/resizer/71x105/products/3050SOH03/medium/12630268.jpg | https://www.hautelookcdn.com/resizer/71x105/products/3050SOH03/medium/12630269.jpg | https://www.hautelookcdn.com/resizer/71x105/products/3050SOH03/medium/12630270.jpg | https://www.hautelookcdn.com/resizer/71x105/products/3050SOH03/medium/12630271.jpg
# url: https://www.nordstromrack.com/events/355416/products/3147919/maaji-azure-heavenly-one-piece-swimsuit?color=BLUE
# brandName: Maaji
# titlename: Azure Heavenly One-Piece Swimsuit
# retailprice: 154
# ...
